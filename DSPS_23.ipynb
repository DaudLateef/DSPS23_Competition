# %%
# !git clone 'https://github.com/UM-Titan/DSPS23.git'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DSPS23
# Out:
# /content/drive/MyDrive/DSPS23

# %%
# !pip install -U --no-cache-dir gdown --pre

# %%
## uncomment line below to download training data
# !gdown '16C6l-CcWEbxFYgarbbKFvK19e-0UYsT2'
# !unzip 'training_data.zip' -d './'
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=16C6l-CcWEbxFYgarbbKFvK19e-0UYsT2
#
# unzip:  cannot find or open training_data.zip, training_data.zip.zip or training_data.zip.ZIP.

# %%
import os
from simple_fxn import cvat2yolo
# location of cvat annotations
if not os.path.isdir('training_data/'):
  print ('Training Data Missing')

if not os.path.isdir('yolo_data/'):
  os.makedirs('yolo_data')
annotation_folder = 'training_data/'
output_path = 'yolo_data/training'
val_path = 'yolo_data/validation'
for annts in os.listdir(annotation_folder):
  json_file = os.path.join(annotation_folder,annts,'annotations','instances_default.json')
  img_path = os.path.join(annotation_folder,annts,'images')
  if(os.path.isfile(json_file)):
    cvat2yolo(annts,json_file,img_path, output_path, val_path)
# Out:
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['LONGITUDINAL', 'MANHOLE', 'PATCHING', 'BLOCK', 'ALLIGATOR', 'TRANSVERSE']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['TRANSVERSE', 'BLOCK', 'SEALING', 'LONGITUDINAL', 'PATCHING', 'ALLIGATOR']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['TRANSVERSE', 'MANHOLE', 'BLOCK', 'LONGITUDINAL', 'ALLIGATOR', 'PATCHING', 'SEALING']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['PATCHING', 'TRANSVERSE', 'LONGITUDINAL', 'BLOCK', 'ALLIGATOR', 'SEALING']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['BLOCK', 'TRANSVERSE', 'LONGITUDINAL', 'ALLIGATOR', 'SEALING', 'PATCHING', 'MANHOLE']

# %%
# !python train_dsps.py --data data/dsps.yaml --epochs 300 --weights yolov5s.pt --cfg yolov5s.yaml  --batch-size 64

# %%
# !ls
# Out:
# data		 requirements.txt     Tutorial_DSPS_TASK2.ipynb
# detect_dsps2.py  runs		      TUTORIA_TASK_2_MODEL_BENCHMARK.ipynb
# detect_dsps.py	 setup.cfg	      utils
# export.py	 simple_fxn.py	      val.py
# hubconf.py	 test_data	      yolo_data
# models		 train_dsps.py	      yolov5s.pt
# __pycache__	 training_data
# README.md	 Tutorial_DSPS.ipynb

# %%
## uncomment to download  test data
# !gdown '1vhaDLAK39pXTLbGFp8nW4dDxKWispzg_'
# !unzip 'test_data.zip' -d './'

# %%
# !python detect_dsps.py --weights runs/train/exp2/weights/last.pt --source 'test_data/' --conf 0.6 --iou_thres 0.99 --augment

# %%
# !pwd
# Out:
# /content/drive/MyDrive/dev/DSPS23/dsps23
